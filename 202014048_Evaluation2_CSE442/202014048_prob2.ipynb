# %% [markdown]
# <a href="https://colab.research.google.com/github/shakil1819/CSE442-Machine-Learning-Sessional/blob/main/202014048_Evaluation2_CSE442/202014048_prob2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing all the required libraries
import pandas as pd
import numpy as np
import sklearn
from pandas.core.dtypes.common import is_numeric_dtype
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr #Ignores the warnings
wr.filterwarnings('ignore')
df=pd.read_csv("https://raw.githubusercontent.com/shakil1819/CSE442-Machine-Learning-Sessional/main/202014048_Evaluation2_CSE442/Party%20Dataset.csv")
df.replace(('yes', 'no'), (1, 0), inplace=True)
df
# Out:
#    Number_of_Guests  Party_Duration_Hours  Music_Volume_dB  Party_Success
# 0                10                   3.0               80              1
# 1                20                   4.0               85              1
# 2                 5                   2.0               70              0
# 3                15                   3.0               75              1
# 4                25                   5.0               90              1
# 5                 8                   2.5               78              0
# 6                12                   3.5               82              1
# 7                18                   4.0               88              1
# 8                 6                   2.0               68              0
# 9                22                   4.5               92              1

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Checking the NULL values

# %%
df.drop('Party_Success', axis=1, inplace=True)
df.head()
# Out:
#    Number_of_Guests  Party_Duration_Hours  Music_Volume_dB
# 0                10                   3.0               80
# 1                20                   4.0               85
# 2                 5                   2.0               70
# 3                15                   3.0               75
# 4                25                   5.0               90

# %% [markdown]
# ### 1.7.5.2 Define dependent (target) and independent (predictor) features

# %%
def fun(row):
    if row["Number_of_Guests"]<=10:
      if row["Party_Duration_Hours"]<=2.5:
        return "Party_Success:No"
      else:
        return "Party_Success:Yes"
    else:
      return "Party_Success:Yes"

df['Party_Success'] = df.apply(fun,axis=1)
df.head()
# Out:
#    Number_of_Guests  Party_Duration_Hours  Music_Volume_dB      Party_Success
# 0                10                   3.0               80  Party_Success:Yes
# 1                20                   4.0               85  Party_Success:Yes
# 2                 5                   2.0               70   Party_Success:No
# 3                15                   3.0               75  Party_Success:Yes
# 4                25                   5.0               90  Party_Success:Yes

# %%
y=df['Party_Success']
y
# Out:
# 0    Party_Success:Yes
# 1    Party_Success:Yes
# 2     Party_Success:No
# 3    Party_Success:Yes
# 4    Party_Success:Yes
# 5     Party_Success:No
# 6    Party_Success:Yes
# 7    Party_Success:Yes
# 8     Party_Success:No
# 9    Party_Success:Yes
# Name: Party_Success, dtype: object

# %%
x=df.drop('Party_Success', axis=1)
x
# Out:
#    Number_of_Guests  Party_Duration_Hours  Music_Volume_dB
# 0                10                   3.0               80
# 1                20                   4.0               85
# 2                 5                   2.0               70
# 3                15                   3.0               75
# 4                25                   5.0               90
# 5                 8                   2.5               78
# 6                12                   3.5               82
# 7                18                   4.0               88
# 8                 6                   2.0               68
# 9                22                   4.5               92

# %%
clf = DecisionTreeClassifier()
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict([[10,3,80]])
# Out:
# array(['Party_Success:Yes'], dtype=object)

# %%
text_rep = tree.export_text(clf)

# %%
print(text_rep)
# Out:
# |--- feature_1 <= 2.75
# |   |--- class: Party_Success:No
# |--- feature_1 >  2.75
# |   |--- class: Party_Success:Yes
