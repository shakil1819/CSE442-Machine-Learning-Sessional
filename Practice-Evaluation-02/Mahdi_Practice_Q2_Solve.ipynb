# %% [markdown]
# <a href="https://colab.research.google.com/github/shakil1819/CSE442-Machine-Learning-Sessional/blob/main/Practice-Evaluation-02/Mahdi_Practice_Q2_Solve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/shakil1819/CSE442-Machine-Learning-Sessional/main/Practice-Evaluation-02/Office%20Dataset.csv')

# %%
import pandas as pd
import numpy as np
import sklearn
from pandas.core.dtypes.common import is_numeric_dtype
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr #Ignores the warnings
wr.filterwarnings('ignore')

# %%
df
# Out:
#     Coffee_Consumption  Desk_Proximity  Hours_of_Sleep  Work_Output
# 0                    3             2.5             7.5           32
# 1                    2             3.0             6.0           24
# 2                    4             2.2             6.8           36
# 3                    5             1.8             5.5           40
# 4                    1             4.0             8.0           18
# 5                    2             2.7             7.2           28
# 6                    3             3.5             6.5           34
# 7                    4             2.0             7.0           38
# 8                    3             3.2             6.3           30
# 9                    2             2.8             6.7           26
# 10                   5             2.3             7.8           42
# 11                   4             3.3             6.1           35
# 12                   1             3.7             5.7           20
# 13                   3             2.6             7.0           32
# 14                   2             3.4             6.5           27
# 15                   4             2.5             7.2           38
# 16                   5             2.1             6.8           40
# 17                   1             3.8             5.0           22
# 18                   3             3.0             7.5           34
# 19                   2             2.9             6.9           28
# 20                   4             2.4             7.3           36

# %%
df.drop('Work_Output', axis=1, inplace=True)
df.head()
# Out:
#    Coffee_Consumption  Desk_Proximity  Hours_of_Sleep
# 0                   3             2.5             7.5
# 1                   2             3.0             6.0
# 2                   4             2.2             6.8
# 3                   5             1.8             5.5
# 4                   1             4.0             8.0

# %%
def fun(row):
    if row["Coffee_Consumption"]<=2.0:
      if row["Desk_Proximity"]<=2.0:
        if row["Hours_of_Sleep"]<=6.0:
          return "Low"
        else:
          return "Medium"
      else:
        return "Medium"
    else:
      if row["Desk_Proximity"]<=3.0:
        if row["Hours_of_Sleep"]<=6.0:
          return "Medium"
        else:
          return "High"
      else:
        return "High"

df['Category'] = df.apply(fun,axis=1)
df.head()
# Out:
#    Coffee_Consumption  Desk_Proximity  Hours_of_Sleep Category
# 0                   3             2.5             7.5     High
# 1                   2             3.0             6.0   Medium
# 2                   4             2.2             6.8     High
# 3                   5             1.8             5.5   Medium
# 4                   1             4.0             8.0   Medium

# %%
y=df['Category']
y
# Out:
# 0       High
# 1     Medium
# 2       High
# 3     Medium
# 4     Medium
# 5     Medium
# 6       High
# 7       High
# 8       High
# 9     Medium
# 10      High
# 11      High
# 12    Medium
# 13      High
# 14    Medium
# 15      High
# 16      High
# 17    Medium
# 18      High
# 19    Medium
# 20      High
# Name: Category, dtype: object

# %%
x=df.drop('Category', axis=1)
x
# Out:
#     Coffee_Consumption  Desk_Proximity  Hours_of_Sleep
# 0                    3             2.5             7.5
# 1                    2             3.0             6.0
# 2                    4             2.2             6.8
# 3                    5             1.8             5.5
# 4                    1             4.0             8.0
# 5                    2             2.7             7.2
# 6                    3             3.5             6.5
# 7                    4             2.0             7.0
# 8                    3             3.2             6.3
# 9                    2             2.8             6.7
# 10                   5             2.3             7.8
# 11                   4             3.3             6.1
# 12                   1             3.7             5.7
# 13                   3             2.6             7.0
# 14                   2             3.4             6.5
# 15                   4             2.5             7.2
# 16                   5             2.1             6.8
# 17                   1             3.8             5.0
# 18                   3             3.0             7.5
# 19                   2             2.9             6.9
# 20                   4             2.4             7.3

# %%
clf = DecisionTreeClassifier()
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict([[3,2.5,7.5]])
# Out:
# array(['High'], dtype=object)
