# %% [markdown]
# <a href="https://colab.research.google.com/github/shakil1819/CSE442-Machine-Learning-Sessional/blob/main/Week_1_2_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#KneeTorque_KNN.ipynb
#Materials available at https://github.com/shakil1819/CSE442-Machine-Learning-Sessional/tree/main/Week%201%2B2

# %%
#Importing the library files...
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fetching the Dataset for training...
path="https://raw.githubusercontent.com/shakil1819/CSE442-Machine-Learning-Sessional/main/Week%201%2B2/Knee-Torque-ZDataSet.csv"
df = pd.read_csv(path)
df.tail()
# Out:
#     Body Weight (kg)  Body Height (m)  Weight-Height Ratio (R)  \
# 52                62             1.62                      NaN
# 53                65             1.50                      NaN
# 54                87             1.87                      NaN
# 55                77             1.88                      NaN
# 56                67             1.73                      NaN
#
#     Internal Moment (M)  Required Torque (N-m) Torque Category
# 52                  NaN                  9.302             Low
# 53                  NaN                  8.624             Low
# 54                  NaN                  7.012        Very Low
# 55                  NaN                  2.514        Very Low
# 56                  NaN                 20.000       Very High
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_64, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_65, *['Body Height (m)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_66, *['Required Torque (N-m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_67, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_68, *['Body Height (m)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_69, *['Required Torque (N-m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_70, *['Torque Category'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_71, *[[['Body Weight (kg)', 'Body Height (m)'], ['Body Height (m)', 'Required Torque (N-m)']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_72, *['Body Weight (kg)', 'Torque Category'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_73, *['Body Height (m)', 'Torque Category'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_74, *['Required Torque (N-m)', 'Torque Category'], **{'inner': 'stick'})
# chart

# %% [markdown]
# ## Plotting the data for understanding

# %%
# Plotting the Body Weight-Height graph...
plt.figure(figsize=(12, 8))
plt.scatter(df["Body Weight (kg)"], df["Body Height (m)"], s=150, c='c')
plt.axis([54, 93, 1.48, 1.92])  # plt.axis([x-min, x-max, y-min, y-max])
plt.xlabel("Body Weight (kg)")
plt.ylabel("Body Height (m)")
plt.title("Body Weight vs. Height")

# Add text labels for each data point
w = df["Body Weight (kg)"].to_numpy()
h = df["Body Height (m)"].to_numpy()
i=0
for v in df["Required Torque (N-m)"].to_numpy():
    plt.text(w[i]+.4, h[i]+.004, v)
    i=i+1

plt.show()

# %% [markdown]
#  ## Plotting the data in different fashion

# %%
# Extract the torque category and body weight
torque_category = df["Torque Category"].values
body_weight = df["Body Weight (kg)"].values

# Get unique torque categories and colors
unique_torque_categories = np.unique(torque_category)
colors = ["#FF0000", "#00008b", "#008000", "#808000", "#008080"]

# Create a scatter plot of the body weight vs. torque category
fig, ax = plt.subplots(figsize=(12, 8))
for i, torque_category in enumerate(unique_torque_categories):
    idxs = np.where(torque_category == torque_category)
    ax.scatter(
        body_weight[idxs],
        i + 5,
        label=torque_category,
        s=150,
        color=colors[i],
        alpha=0.9,
    )

ax.legend()

# Add text labels for each data point
font = {"family": "sans serif", "color": "black", "weight": "normal", "size": 11}
for i, v in enumerate(df["Required Torque (N-m)"].to_numpy()):
    ax.text(body_weight[i] + 0.4, i + 5 + 0.004, v, fontdict=font)

# Set the labels and title
ax.set_xlabel("Body Weight (kg)", fontdict=font, fontsize=16)
ax.set_ylabel("Torque Category", fontdict=font, fontsize=16)
plt.title("Torque vs. Body Weight", fontdict=font, fontsize=16)

# Add a new point with label "New?"
plt.scatter(82, 4, s=150, c="#000000")
plt.text(82 + 0.4, 4 + 0.004, "New?", fontname="sans serif", fontsize=12)

plt.show()

# %% [markdown]
# ## Code to check NULL values in a data-frame with corresponding outputs

# %%
df.isnull().sum()
# Out:
# Body Weight (kg)           0
# Body Height (m)            0
# Weight-Height Ratio (R)    8
# Internal Moment (M)        8
# Required Torque (N-m)      0
# Torque Category            0
# dtype: int64

# %% [markdown]
# ## Dropping the NULL value records

# %%
df1 = df.dropna()
df1.tail(10)
# Out:
#     Body Weight (kg)  Body Height (m)  Weight-Height Ratio (R)  \
# 39                85             1.80                   47.222
# 40                85             1.85                   45.946
# 41                85             1.90                   44.737
# 42                90             1.60                   56.250
# 43                90             1.65                   54.545
# 44                90             1.70                   52.941
# 45                90             1.75                   51.429
# 46                90             1.80                   50.000
# 47                90             1.85                   48.649
# 48                90             1.90                   47.368
#
#     Internal Moment (M)  Required Torque (N-m) Torque Category
# 39               1.3841                 13.565            High
# 40               1.4226                 13.941            High
# 41               1.4610                 14.318            High
# 42               1.3027                 12.767          Medium
# 43               1.3434                 13.166            High
# 44               1.3841                 13.565            High
# 45               1.4249                 13.964            High
# 46               1.4656                 14.363            High
# 47               1.5063                 14.761            High
# 48               1.5470                 15.160            High

# %% [markdown]
# ## Determining dependent and independent features

# %%
# Extract the required torque and drop weight-height ratio, internal moment, and torque category columns
y = df1['Required Torque (N-m)']
X = df1.drop([ 'Weight-Height Ratio (R)', 'Internal Moment (M)', 'Required Torque (N-m)', 'Torque Category'], axis=1)

X.describe()
# Out:
#        Body Weight (kg)  Body Height (m)
# count          49.00000        49.000000
# mean           75.00000         1.750000
# std            10.10363         0.101036
# min            60.00000         1.600000
# 25%            65.00000         1.650000
# 50%            75.00000         1.750000
# 75%            85.00000         1.850000
# max            90.00000         1.900000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_75, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_76, *['Body Height (m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_77, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_78, *['Body Height (m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_79, *[[['Body Weight (kg)', 'Body Height (m)']]], **{})
# chart

# %% [markdown]
# ## Splitting Train and Test data

# %%
# Splitting Train and Test data (75% & 25%, respectively)
from sklearn.model_selection import train_test_split
#SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

len(X)	     #57
len(X_train) # 42
len(X_test)  # 15
X_test
# Out:
#     Body Weight (kg)  Body Height (m)
# 31                80             1.75
# 3                 60             1.75
# 43                90             1.65
# 47                90             1.85
# 13                65             1.90
# 4                 60             1.80
# 5                 60             1.85
# 2                 60             1.70
# 25                75             1.80
# 27                75             1.90
# 42                90             1.60
# 11                65             1.80
# 15                70             1.65
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(X_test, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(X_test, *['Body Height (m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(X_test, *['Body Weight (kg)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(X_test, *['Body Height (m)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(X_test, *[[['Body Weight (kg)', 'Body Height (m)']]], **{})
# chart

# %% [markdown]
# ## Creating a test dataset with single record

# %%
X_test2 = X_test[:1]
X_test2
# Out:
#     Body Weight (kg)  Body Height (m)
# 31                80             1.75

# %% [markdown]
# ## Feature Scaling for KNN Regression

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit only on x_train...
scaler.fit(X_train)
X_t = X_test
X_t2 = X_test2
# Scale both X_train and X_test...
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_test2 = scaler.transform(X_test2)

# %% [markdown]
# ## Organizing the scaled data into 𝐷𝑎𝑡𝑎𝐹𝑟𝑎𝑚𝑒 again

# %%
col_names = ["Body weight (kg)", "Body Height (m) 1"]# "Meight-weight Ratio (A)", "Internal Moment (1)"]
scaled_df = pd.DataFrame(X_train, columns=col_names)
scaled_df.describe().T
# Out:
#                    count          mean       std       min       25%  \
# Body weight (kg)    36.0 -6.846375e-16  1.014185 -1.737842 -0.649802
# Body Height (m) 1   36.0  1.949058e-15  1.014185 -1.409637 -0.916948
#
#                         50%       75%       max
# Body weight (kg)  -0.105782  0.982259  1.526279
# Body Height (m) 1  0.068429  1.053806  1.546495

# %% [markdown]
# # K-NN Regression

# %% [markdown]
# ###  Training and Predicting using K-NN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# Create a KNN regressor
K = 5
regressor = KNeighborsRegressor(n_neighbors=K)

# Fit the regressor to the training data
regressor.fit(X_train, y_train)

# Predict the required torque for the test data
y_pred = regressor.predict(X_test)

# Print the predicted torque
print(y_pred)
# Out:
# [12.4918   9.80566 12.9662  14.2694  11.0422  10.36414 10.825    9.33568
#  11.7472  12.434   12.443   10.8518  10.03592]

# %% [markdown]
# ###  Predicting for a single record as test

# %%
y_pred2 = regressor.predict(X_test2)
y_pred2
# Out:
# array([12.4918])

# %%
pred_df = X_t2
pred_df
# Out:
#     Body Weight (kg)  Body Height (m)
# 31                80             1.75

# %% [markdown]
# ### Evaluating the results for K-NN Regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Evaluating the Algorithm for Kai Regression...
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

# Print the evaluation metrics
print('Mean Absolute Error:', mae)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 0.37348923076923085
# Mean Squared Error: 0.20652977200000017
# Root Mean Squared Error: 0.4544554675653052

# %%
#R2 can be calculated
regressor.score(X_test,y_test)
# Out:
# 0.9281009460592686

# %%
y.describe()
# Out:
# count    49.000000
# mean     11.636300
# std       1.707826
# min       8.511100
# 25%      10.240000
# 50%      11.636000
# 75%      12.811000
# max      15.160000
# Name: Required Torque (N-m), dtype: float64

# %% [markdown]
# ### Finding the Best K for K-NN Regression

# %%
import matplotlib.pyplot as plt
import numpy as np

# Finding the best i for non regression...
error = []

# calculating error for values between 1 and 29
for i in range(1, 30):
    # Create a KNN regressor with k neighbors
    knn = KNeighborsRegressor(n_neighbors=i)

    # Fit the regressor to the training data
    knn.fit(X_train, y_train)

    # Predict the required torque for the test data
    pred_i = knn.predict(X_test)

    # Calculate the mean absolute error
    mae = mean_absolute_error(y_test, pred_i)

    # Append the mean absolute error to the error list
    error.append(mae)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.plot(range(1,30), error, color='red',linestyle='dashed',marker='o',markerfacecolor='blue',markersize=10)
plt.title('K value MAE')
plt.xlabel('K value')
plt.ylabel('Mean Absolute Error (MAE)')
# Out:
# Text(0, 0.5, 'Mean Absolute Error (MAE)')

# %% [markdown]
# ###  Predicting with minimum error position as K=2

# %%
import numpy as np

# print(min(error))
# print(np.array(error).argmin())
print(min(error[2:]))
# print(np.array(error[2:]).argmin()+2)
K_neigh = np.array(error[2:]).argmin()+2

knn_reg = KNeighborsRegressor(n_neighbors=4)
knn_reg.fit(X_train,y_train)
y_pred_reg = knn_reg.predict(X_test)
r2_reg = knn_reg.score(X_test,y_test)

mae_reg = mean_absolute_error(y_test,y_pred_reg)
mse_reg = mean_squared_error(y_test,y_pred)
rmse_reg = mean_squared_error(y_test,y_pred_reg,squared=False)
print(f'r2: {r2_reg}, \name: {mae_reg}, \nmse: {mse_reg} \nmrse: {rmse_reg}')
# Out:
# 0.334232692307693
# r2: 0.9310267102194476,
# ame: 0.334232692307693,
# mse: 0.20652977200000017
# mrse: 0.4451129351614906
